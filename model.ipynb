# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
test1 = './Hindi/test.mp3'
data, sample = librosa.load(test1, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample1, x_axis = 'time', offset= 0.0)

# %%
test2 = './Hindi/Rahul_Subramanian_1.mp3'
data, sample1 = librosa.load(test2, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample1, x_axis = 'time', offset= 0.0)

# %%
test3 = './Hindi/Yahya_Bootwaala_1.mp3'
data, sample3 = librosa.load(test3, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample3, x_axis = 'time', offset= 0.0)

# %%
test4 = './Hindi/Rahul_3.mp3'
data, sample4 = librosa.load(test4, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample4, x_axis = 'time', offset= 0.0)

# %%
test5 = './Hindi/Rahul_4.mp3'
data, sample5 = librosa.load(test5, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample5, x_axis = 'time', offset= 0.0)

# %%
test6 = './Hindi/Aakash_1.mp3'
data, sample6 = librosa.load(test6, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample6, x_axis = 'time', offset= 0.0)

# %%
test7 = './Hindi/Divakar_1.mp3'
data, sample7 = librosa.load(test7, sr = 22050, mono = True, offset = 0.0, duration = 50, res_type = 'kaiser_best')

# %%
librosa.display.waveshow(data, sr=sample7, x_axis = 'time', offset= 0.0)
